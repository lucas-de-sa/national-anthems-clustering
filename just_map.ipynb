# %% [markdown]
# ![alt text](Images/word_clouds.png "Title")

# %%
m
# Out:
# <iframe src="data:text/html;charset=utf-8;base64,..." width="1300" height="675"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>
